# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
dataset1=pd.read_csv('ci_transaction.csv')
dataset1.head()
# Out:
#    id        date  days_after_open day_of_week  hours_after_open  drink_id  \
# 0   0  2019-07-22                0         Mon                 0         5
# 1   1  2019-07-22                0         Mon                 0         5
# 2   2  2019-07-22                0         Mon                 0         2
# 3   3  2019-07-22                0         Mon                 0         2
# 4   4  2019-07-22                0         Mon                 0         5
#
#    quantity raining  study_area_id
# 0         1      No              3
# 1         1      No              1
# 2         1      No              5
# 3         1      No              6
# 4         1      No              5

# %%
dataset1.tail()
# Out:
#           id        date  days_after_open day_of_week  hours_after_open  \
# 27709  27709  2019-12-22              153         Sun                 5
# 27710  27710  2019-12-22              153         Sun                 5
# 27711  27711  2019-12-22              153         Sun                 5
# 27712  27712  2019-12-22              153         Sun                 5
# 27713  27713  2019-12-22              153         Sun                 5
#
#        drink_id  quantity raining  study_area_id
# 27709        14         2      No              3
# 27710         6         1      No              3
# 27711        12         1      No              0
# 27712         9         1      No              4
# 27713         9         1      No              3

# %%
dataset1.shape
# Out:
# (27714, 9)

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27714 entries, 0 to 27713
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                27714 non-null  int64
#  1   date              27714 non-null  object
#  2   days_after_open   27714 non-null  int64
#  3   day_of_week       27714 non-null  object
#  4   hours_after_open  27714 non-null  int64
#  5   drink_id          27714 non-null  int64
#  6   quantity          27714 non-null  int64
#  7   raining           27171 non-null  object
#  8   study_area_id     27714 non-null  int64
# dtypes: int64(6), object(3)
# memory usage: 1.9+ MB

# %%
dataset1.describe()
# Out:
#                  id  days_after_open  hours_after_open      drink_id  \
# count  27714.000000     27714.000000      27714.000000  27714.000000
# mean   13856.500000       107.558959          2.375947      8.030165
# std     8000.487016        36.843121          1.681598      4.875940
# min        0.000000         0.000000          0.000000      0.000000
# 25%     6928.250000        89.000000          1.000000      4.000000
# 50%    13856.500000       117.000000          2.000000      8.000000
# 75%    20784.750000       136.000000          4.000000     12.000000
# max    27713.000000       153.000000          5.000000     16.000000
#
#            quantity  study_area_id
# count  27714.000000   27714.000000
# mean       1.266905       2.166558
# std        0.613148       2.131795
# min        1.000000      -1.000000
# 25%        1.000000       0.000000
# 50%        1.000000       1.000000
# 75%        1.000000       4.000000
# max        4.000000       6.000000

# %%
plt.figure(figsize=(10,10))
pd1=dataset1['days_after_open']
sns.countplot(pd1)

# %%
pd2=dataset1['study_area_id']
sns.countplot(pd2)

# %%
pd3=dataset1['raining']
sns.countplot(pd3)

# %%
pd4=dataset1['drink_id']
sns.countplot(pd4)

# %%
pd5=dataset1['hours_after_open']
sns.countplot(pd5)

# %%
plt.figure(figsize=(20,10))
plt.xlabel("days_after_open")
plt.ylabel("days_of_week")
sns.scatterplot(x='days_after_open',y='day_of_week',hue='date',data=dataset1)

# %%
d1=dataset1['days_after_open'].value_counts()
d1
# Out:
# 135    452
# 128    432
# 142    422
# 134    418
# 144    417
#       ...
# 4       39
# 19      38
# 5       38
# 13      36
# 14      34
# Name: days_after_open, Length: 154, dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.xlabel("hours_after_open")
plt.ylabel("days_of_week")
sns.scatterplot(x='hours_after_open',y='day_of_week',hue='date',data=dataset1)

# %%
plt.figure(figsize=(20,10))
plt.xlabel("hours_after_open")
plt.ylabel("days_of_week")
sns.scatterplot(x='hours_after_open',y='day_of_week',hue='raining',data=dataset1)

# %%
plt.figure(figsize=(20,10))
plt.xlabel("raining")
plt.ylabel("days_of_week")
sns.scatterplot(x='raining',y='day_of_week',hue='date',data=dataset1)

# %%
plt.figure(figsize=(20,10))
plt.xlabel("raining")
plt.ylabel("hours_after_open")
sns.scatterplot(x='raining',y='hours_after_open',hue='day_of_week',data=dataset1)

# %%
plt.figure(figsize=(20,10))
plt.xlabel("raining")
plt.ylabel("study_area_id")
sns.scatterplot(x='raining',y='study_area_id',hue='date',data=dataset1)

# %%
plt.figure(figsize=(20,10))
plt.xlabel("raining")
plt.ylabel("study_area_id")
sns.scatterplot(x='raining',y='study_area_id',hue='day_of_week',data=dataset1)

# %%
plt.figure(figsize=(20,10))
plt.xlabel("day_of_week")
plt.ylabel("hours_after_open")
sns.scatterplot(x='day_of_week',y='hours_after_open',hue='date',data=dataset1)

# %%
pivot1=\
dataset1.pivot_table(index='day_of_week',values='hours_after_open',aggfunc=np.sum)
plt.figure(figsize=(15,10))
pivot1.plot(kind='bar',color='yellow')
plt.xlabel('week day')
plt.ylabel('hours of days')
plt.show()

# %%
dataset1['hours_after_open'].sum()
# Out:
# 65847

# %%
pivot1=\
dataset1.pivot_table(index='day_of_week',values='days_after_open',aggfunc=np.mean)
plt.figure(figsize=(15,10))
pivot1.plot(kind='bar',color='yellow')
plt.xlabel('week day')
plt.ylabel('opening of days')
plt.show()

# %%
dataset1['hours_after_open'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5], dtype=int64)

# %%
pt=\
dataset1.pivot_table(index='day_of_week',values='hours_after_open')
plt.figure(figsize=(15,10))
pt.plot(kind='bar',color='green')
plt.xlabel('week day')
plt.ylabel('hours of open')
plt.show()

# %%
pivot2=\
dataset1.pivot_table(index='day_of_week',values='hours_after_open',aggfunc=np.mean)
plt.figure(figsize=(15,10))
pivot2.plot(kind='bar',color='yellow')
plt.xlabel('week day')
plt.ylabel('opening of hours')
plt.show()

# %%
pivot3=\
dataset1.pivot_table(index='days_after_open',values='hours_after_open',aggfunc=np.mean)
plt.figure(figsize=(15,20))
pivot3.plot(kind='bar',color='yellow')
plt.xlabel('opening of days')
plt.ylabel('opening of hours')
plt.show()

# %%
pivot4=\
dataset1.pivot_table(index='raining',values='study_area_id',aggfunc=np.mean)
plt.figure(figsize=(15,10))
pivot4.plot(kind='bar',color='red')
plt.xlabel('raining factors')
plt.ylabel('study_area_id')
plt.show()

# %%
ratings=dataset1[['day_of_week','hours_after_open']]
ratings_df=ratings.groupby(['day_of_week']).agg(np.max)
ratings_df.head(10)
# Out:
#              hours_after_open
# day_of_week
# Fri                         5
# Mon                         5
# Sat                         5
# Sun                         5
# Thu                         5
# Tue                         5
# Wed                         5

# %%
count_ratings=dataset1.groupby('day_of_week').count()
count_ratings['perc_total']=round(count_ratings['hours_after_open']*100/count_ratings['hours_after_open'].sum(),2)
count_ratings
# Out:
#                id  date  days_after_open  hours_after_open  drink_id  \
# day_of_week
# Fri          3900  3900             3900              3900      3900
# Mon          3680  3680             3680              3680      3680
# Sat          3719  3719             3719              3719      3719
# Sun          3770  3770             3770              3770      3770
# Thu          4204  4204             4204              4204      4204
# Tue          3966  3966             3966              3966      3966
# Wed          4475  4475             4475              4475      4475
#
#              quantity  raining  study_area_id  perc_total
# day_of_week
# Fri              3900     3829           3900       14.07
# Mon              3680     3607           3680       13.28
# Sat              3719     3645           3719       13.42
# Sun              3770     3693           3770       13.60
# Thu              4204     4124           4204       15.17
# ...

# %%
count_ratings['perc_total'].plot.bar()

# %%
total_number_of_works_for_a_particular_day=dataset1.groupby('day_of_week')['hours_after_open'].count()
total_number_of_works_for_a_particular_day
# Out:
# day_of_week
# Fri    1
# Mon    1
# Sat    1
# Sun    1
# Thu    1
# Tue    1
# Wed    1
# Name: hours_after_open, dtype: int64

# %%
sns.pairplot(dataset1)

# %%
dataset1.corr()
# Out:
#                         id  days_after_open  hours_after_open  drink_id  \
# id                1.000000         0.936678          0.040447 -0.000327
# days_after_open   0.936678         1.000000          0.039701 -0.001671
# hours_after_open  0.040447         0.039701          1.000000 -0.001335
# drink_id         -0.000327        -0.001671         -0.001335  1.000000
# quantity         -0.004850        -0.003502         -0.000661 -0.001921
# study_area_id    -0.016304        -0.021189         -0.009214  0.004227
#
#                   quantity  study_area_id
# id               -0.004850      -0.016304
# days_after_open  -0.003502      -0.021189
# hours_after_open -0.000661      -0.009214
# drink_id         -0.001921       0.004227
# quantity          1.000000       0.006956
# study_area_id     0.006956       1.000000

# %%
plt.figure(figsize=(15,10))
sns.heatmap(dataset1.corr(),annot=True,fmt='.0%')

# %%
dataset1.pivot_table(values='days_after_open',columns='day_of_week',aggfunc=lambda x: x.mode())
# Out:
# day_of_week      Fri  Mon  Sat  Sun  Thu  Tue  Wed
# days_after_open  144  140  138  139  150  134  135

# %%
dataset1.pivot_table(values='hours_after_open',columns='day_of_week',aggfunc=lambda x: x.mode())
# Out:
# day_of_week       Fri  Mon  Sat  Sun  Thu  Tue  Wed
# hours_after_open    1    1    1    1    2    1    1

# %%
dataset1.pivot_table(values='hours_after_open',columns='day_of_week',aggfunc=lambda x: x.std())
# Out:
# day_of_week            Fri       Mon       Sat       Sun       Thu       Tue  \
# hours_after_open  1.691101  1.689387  1.673409  1.662044  1.683947  1.678684
#
# day_of_week            Wed
# hours_after_open  1.691199

# %%
dataset1.pivot_table(values='day_of_week',columns='study_area_id',aggfunc=lambda x:x.mode())
# Out:
# study_area_id   -1    0    1    2    3    4    5    6
# day_of_week    Wed  Thu  Thu  Wed  Wed  Wed  Wed  Wed

# %%
pivot6=\
dataset1.pivot_table(index='day_of_week',values='study_area_id',aggfunc=np.mean)
plt.figure(figsize=(15,10))
pivot6.plot(kind='bar',color='green')
plt.xlabel('week day')
plt.ylabel('study_area_id')
plt.show()

# %%
x1=dataset1.pivot_table(values='study_area_id', index='day_of_week')
x1.head()
# Out:
#              study_area_id
# day_of_week
# Fri               2.230000
# Mon               2.186957
# Sat               2.208658
# Sun               2.097878
# Thu               2.014034

# %%
x2=dataset1.pivot_table(values='days_after_open',index='date')
x2.head()
# Out:
#             days_after_open
# date
# 2019-07-22                0
# 2019-07-23                1
# 2019-07-24                2
# 2019-07-25                3
# 2019-07-26                4

# %%
x2.tail()
# Out:
#             days_after_open
# date
# 2019-12-18              149
# 2019-12-19              150
# 2019-12-20              151
# 2019-12-21              152
# 2019-12-22              153

# %%
x3=dataset1.pivot_table(values='days_after_open',index='day_of_week')
x3.head()
# Out:
#              days_after_open
# day_of_week
# Fri               109.281795
# Mon               105.926359
# Sat               111.037107
# Sun               111.629443
# Thu               105.872027

# %%
x4=dataset1.pivot_table(values='hours_after_open',index='date')
x4.head()
# Out:
#             hours_after_open
# date
# 2019-07-22          2.080000
# 2019-07-23          2.306452
# 2019-07-24          2.028986
# 2019-07-25          2.158730
# 2019-07-26          2.025641

# %%
x4.tail()
# Out:
#             hours_after_open
# date
# 2019-12-18          2.465174
# 2019-12-19          2.375303
# 2019-12-20          2.332353
# 2019-12-21          2.321937
# 2019-12-22          2.415473

# %%
x5=dataset1.pivot_table(values='hours_after_open',index='day_of_week')
x5.head()
# Out:
#              hours_after_open
# day_of_week
# Fri                  2.386154
# Mon                  2.372283
# Sat                  2.356816
# Sun                  2.385942
# Thu                  2.383920

# %%
x6=dataset1.pivot_table(values='study_area_id',index='day_of_week')
x6.head()
# Out:
#              study_area_id
# day_of_week
# Fri               2.230000
# Mon               2.186957
# Sat               2.208658
# Sun               2.097878
# Thu               2.014034
